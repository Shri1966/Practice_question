# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# (a) Draw 100 samples x = [x1 x2] from a 2-dimensional Gaussian distribution with mean [0,0] and identity covariance matrix.

# %%
M  = [0,0]
C = [[1,0],[0,1]]
x1,x2 = np.random.multivariate_normal(M, C, 100,).T
plt.plot(x1,x2,'.')
plt.show()

# %% [markdown]
# (b) If the mean is [−1, 1]

# %%
M  = [-1,1]
C = [[1,0],[0,1]]
x1,x2 = np.random.multivariate_normal(M, C, 100,).T
plt.plot(x1,x2,'.')
plt.show()

# %% [markdown]
# (c) If you double the variance of each component.

# %%
M  = [0,0]
C = [[2,0],[0,2]]
x1,x2 = np.random.multivariate_normal(M, C, 100,).T
plt.plot(x1,x2,'.')
plt.show()

# %% [markdown]
# (d) If the covariance matrix is changed to  [ 1  , 0.5]
#                                             [0.5 ,   1]

# %%
M  = [0,0]
C = [[1,0.5],[0.5,1]]
x1,x2 = np.random.multivariate_normal(M, C, 100,).T
plt.plot(x1,x2,'.')
plt.show()

# %% [markdown]
# (e) If the covariance matrix is changed to  [  1  , -0.5]
#                                             [-0.5 ,   1 ]

# %%
M  = [0,0]
C = [[1,-0.5],[-0.5,1]]
x1,x2 = np.random.multivariate_normal(M, C, 100,).T
plt.plot(x1,x2,'.')
plt.show()
